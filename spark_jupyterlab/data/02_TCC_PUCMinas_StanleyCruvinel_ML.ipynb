# %%
from pyspark.sql import SparkSession
from pyspark.ml.linalg import Vectors
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.feature import RFormula

# %%
spark = SparkSession.\
        builder.\
        appName("tcc_pucminas_ml_fretes").\
        master("spark://spark-master:7077").\
        config("spark.executor.memory", "7G").\
        getOrCreate()

# %%
fretes = spark.read.csv(path="data/fretes.csv", sep=";", header=True)

# %%
dataset_prep = fretes.selectExpr("upper(UF_origem) as uf_ori",
                            "upper(UF_Destino) as uf_dst",
                            "KM as km",
                            "regexp_replace(Preco,'([ˆ.]|[^,]*$)|[ˆ,]','') as preco").\
                selectExpr("*","format_number(preco/km,4) as preco_km").\
                where("not isnull(preco_km) and Pton = 0 and PED = 0")

# %%
dataset_prep.show()
# Out:
# +------+------+----+------+--------+
# |uf_ori|uf_dst|  km| preco|preco_km|
# +------+------+----+------+--------+
# |    CE|    SC|3520|   150|  0.0426|
# |    SP|    MG| 537|   300|  0.5587|
# |    PA|    PA| 265|     3|  0.0113|
# |    SP|    SP| 162|    25|  0.1543|
# |    RS|    SP|1073|  2000|  1.8639|
# |    TO|    GO| 625|  1000|  1.6000|
# |    SP|    SP| 327|   200|  0.6116|
# |    SP|    SP|  21|   318| 15.1429|
# |    SP|    SP| 282|   500|  1.7730|
# |    RJ|    MG| 341|   750|  2.1994|
# |    RJ|    MG| 341|   750|  2.1994|
# |    PA|    MG|2035|   200|  0.0983|
# |    PA|    SP|2182|   250|  0.1146|
# |    SP|    ES|1152|  5800|  5.0347|
# |    PB|    PE| 115|  2500| 21.7391|
# |    MT|    MG|1988|   700|  0.3521|
# |    MG|    MT| 934|  3800|  4.0685|
# |    SP|    PE|2566| 12000|  4.6765|
# |    SP|    PA|2438|  9000|  3.6916|
# |    SP|    BA|1910|  9000|  4.7120|
# +------+------+----+------+--------+
# only showing top 20 rows

# %%
dataset_prep.count()
# Out:
# 542

# %%
# Preparando os dados para aplicão fórmula R.
formula = RFormula(
    formula="uf_dst ~ uf_ori + preco_km",
    featuresCol="features",
    labelCol="label")

# %%
dataset = formula.fit(dataset_prep).transform(dataset_prep)

# %%
(training, test) = dataset.randomSplit([0.95, 0.05])

# %%
training.show(10, False)
# Out:
# +------+------+----+-----+--------+-----------------------+-----+
# |uf_ori|uf_dst|km  |preco|preco_km|features               |label|
# +------+------+----+-----+--------+-----------------------+-----+
# |AC    |BA    |4567| 10  |0.0022  |(283,[16,42],[1.0,1.0])|3.0  |
# |BA    |BA    |272 | 700 |2.5735  |(283,[0,172],[1.0,1.0])|3.0  |
# |BA    |BA    |517 | 2500|4.8356  |(283,[0,26],[1.0,1.0]) |3.0  |
# |BA    |BA    |517 | 2500|4.8356  |(283,[0,26],[1.0,1.0]) |3.0  |
# |BA    |BA    |517 | 2500|4.8356  |(283,[0,26],[1.0,1.0]) |3.0  |
# |BA    |BA    |517 | 2500|4.8356  |(283,[0,26],[1.0,1.0]) |3.0  |
# |BA    |BA    |517 | 2500|4.8356  |(283,[0,26],[1.0,1.0]) |3.0  |
# |BA    |BA    |517 | 2500|4.8356  |(283,[0,26],[1.0,1.0]) |3.0  |
# |BA    |BA    |517 | 2500|4.8356  |(283,[0,26],[1.0,1.0]) |3.0  |
# |BA    |BA    |517 | 2500|4.8356  |(283,[0,26],[1.0,1.0]) |3.0  |
# +------+------+----+-----+--------+-----------------------+-----+
# only showing top 10 rows

# %%
training.printSchema()
# Out:
# root
#  |-- uf_ori: string (nullable = true)
#  |-- uf_dst: string (nullable = true)
#  |-- km: string (nullable = true)
#  |-- preco: string (nullable = true)
#  |-- preco_km: string (nullable = true)
#  |-- features: vector (nullable = true)
#  |-- label: double (nullable = false)

# %%
# Criando a instância da Regressão Logítica . Esssa instância é o Estimador.
lr = LogisticRegression(maxIter=100, regParam=0.01)
# Para imprimir os parametoros, instrução, e valores padrões.
#print("LogisticRegression parâmetros:\n" + lr.explainParams() + "\n")

# %%
# Learn a LogisticRegression model. This uses the parameters stored in lr.
model1 = lr.fit(training)

# %%
# A transformação é dada pela o estimador,
# Podemos ver os parâmetros do fit().
# Instancia do modelo mode1 da regressão logística .
#print(model1.extractParamMap())

# %%
# Podemos, alternativamente, especificar parâmetros usando um dicionário Python com um paramMap
paramMap = {lr.maxIter: 100}
paramMap[lr.maxIter] = 30  # Especificando parâmero, sobrescrevendo o maxIter.
paramMap.update({lr.regParam: 0.1, lr.threshold: 0.55})  # Especificando múltiplos parâmetros.

# %%
# Pode combinar o paramMaps, são dicionários no python.
paramMap2 = {lr.probabilityCol: "myProbability"}  # Alterando name  da coluna
paramMapCombined = paramMap.copy()
paramMapCombined.update(paramMap2)

# %%
# Agora aprendizado comm o novo modelo model2 usando os parâmetros do paramMapCombined.
# paramMapCombined sobrescreve todos os parâmetros configurados anteriormente via lr.set* methods.
model2 = lr.fit(training, paramMapCombined)
#print(model2.extractParamMap())

# %%
test.show(10)
# Out:
# +------+------+----+-----+--------+--------------------+-----+
# |uf_ori|uf_dst|  km|preco|preco_km|            features|label|
# +------+------+----+-----+--------+--------------------+-----+
# |    BA|    BA| 517| 2500|  4.8356|(283,[0,26],[1.0,...|  3.0|
# |    BA|    BA| 517| 2500|  4.8356|(283,[0,26],[1.0,...|  3.0|
# |    BA|    PA|2033| 7850|  3.8613|(283,[0,22],[1.0,...|  7.0|
# |    BA|    PB| 921| 3900|  4.2345|(283,[0,23],[1.0,...|  9.0|
# |    BA|    PE| 706| 3750|  5.3116|(283,[0,27],[1.0,...|  4.0|
# |    BA|    PE| 805| 3750|  4.6584|(283,[0,24],[1.0,...|  4.0|
# |    BA|    RJ|1629| 6200|  3.8060|(283,[0,20],[1.0,...|  0.0|
# |    BA|    RJ|1629| 6200|  3.8060|(283,[0,20],[1.0,...|  0.0|
# |    PA|    CE|1660| 6500|  3.9157|(283,[4,214],[1.0...|  5.0|
# |    PB|    SP|2703| 6000|  2.2198|(283,[15,163],[1....|  2.0|
# +------+------+----+-----+--------+--------------------+-----+
# only showing top 10 rows

# %%
# Gerandoa as previsões na partição test de dados utilizando a transformação do método transform() .
# LogisticRegression.transform só utilizará a coluna 'features'.
# Nota que no model2.transform() a nova coluna é "myProbability" diferente do padrão do método lr.probabilityCol.
prediction = model2.transform(test)
result = prediction.select("features", "label", "myProbability", "prediction") \
    .collect()

# %%
prediction = model2.transform(test)
result = prediction.select("features", "label", "myProbability", "prediction") \
    .collect()

# %%
i = 0
print (test.columns[0:5])
for row in result:
    print (test.collect()[i][:5])
    i += 1
    print("features (Características do dado)= %s\nlabel = %s <-> prob = %s\nprediction = %s\n"
          % (row.features, row.label,  row.prediction, row.myProbability))
# Out:
# ['uf_ori', 'uf_dst', 'km', 'preco', 'preco_km']
# ('BA', 'BA', '517', ' 2500', '4.8356')
# features (Características do dado)= (283,[0,26],[1.0,1.0])
# label = 3.0 <-> prob = 3.0
# prediction = [0.05174507220777835,0.02313623662989299,0.023164175975093227,0.7190582627279983,0.03577502206168011,0.02323584023193223,0.014733057604374118,0.01816496575646411,0.01784666951358778,0.016549833286149774,0.008378294715170778,0.007556691089299961,0.005787851985004157,0.0058435652330021326,0.00546766924561357,0.004360614348286188,0.0037387880295079046,0.003637964531501942,0.001920320557430431,0.001600169155965197,0.0017076514779302604,0.00170675254881067,0.000981694787090989,0.0009816947870909898,0.0009816947870909898,0.0009816947870909898,0.0009577519391618146]
#
# ('BA', 'BA', '517', ' 2500', '4.8356')
# features (Características do dado)= (283,[0,26],[1.0,1.0])
# label = 3.0 <-> prob = 3.0
# prediction = [0.05174507220777835,0.02313623662989299,0.023164175975093227,0.7190582627279983,0.03577502206168011,0.02323584023193223,0.014733057604374118,0.01816496575646411,0.01784666951358778,0.016549833286149774,0.008378294715170778,0.007556691089299961,0.005787851985004157,0.0058435652330021326,0.00546766924561357,0.004360614348286188,0.0037387880295079046,0.003637964531501942,0.001920320557430431,0.001600169155965197,0.0017076514779302604,0.00170675254881067,0.000981694787090989,0.0009816947870909898,0.0009816947870909898,0.0009816947870909898,0.0009577519391618146]
#
# ('BA', 'PA', '2033', ' 7850', '3.8613')
# features (Características do dado)= (283,[0,22],[1.0,1.0])
# label = 7.0 <-> prob = 7.0
# prediction = [0.05570118627069238,0.025367311318859925,0.025396781911957423,0.03164090280043183,0.03886580821121894,0.025473286725429527,0.016271907558085018,0.6802452135376763,0.019654197888427698,0.018247198296483396,0.009312550087512065,0.00840667305278916,0.006451584748679686,0.006513284410406138,0.006096934405731839,0.004868697440733713,0.004177482211038696,0.0040653131551173435,0.0021503823247346066,0.001792595853236116,0.0019127483542153568,0.001911743588597551,0.0011006053019627978,0.0011006053019627978,0.0011006053019627987,0.0011006053019627987,0.001073794640094063]
#
# ('BA', 'PB', '921', ' 3900', '4.2345')
# features (Características do dado)= (283,[0,23],[1.0,1.0])
# label = 9.0 <-> prob = 9.0
# prediction = [0.05648952046234261,0.025816111531596526,0.025845934272705526,0.03217306246981077,0.0394844706919266,0.025923545204030767,0.016583164227608096,0.02036944525087119,0.02001914498639303,0.6728235953207161,0.009502541646540687,0.008579667475467479,0.006586915908543552,0.006649827692402702,0.0062252798567796995,0.004972451839163612,0.004267129850950241,0.0041526527312842855,0.0021974967066621933,0.0018320182593742922,0.0019547609581873635,0.0019537345594972575,0.0011249852058323514,0.0011249852058323514,0.0011249852058323523,0.0011249852058323523,0.0010975872738159683]
#
# ('BA', 'PE', '706', ' 3750', '5.3116')
# features (Características do dado)= (283,[0,27],[1.0,1.0])
# label = 4.0 <-> prob = 4.0
#
# ('SE', 'RS', '3255', ' 8000', '2.4578')
# features (Características do dado)= (283,[6,170],[1.0,1.0])
# label = 1.0 <-> prob = 3.0
# prediction = [0.09715122681335338,0.07314251938129773,0.07328326421888971,0.3503570858177979,0.08134916872700039,0.046025808982404284,0.041677531831185416,0.03351378478043772,0.0319002370672029,0.02935514865697647,0.0213299834337065,0.018974318988560376,0.01409847149780849,0.020242832273891467,0.013244734554510865,0.010362042396613303,0.008788308413439909,0.00853617904300987,0.004371051069751184,0.0036215850857585752,0.0038722591787319696,0.0038701587475985103,0.0021973618877347703,0.0021973618877347703,0.0021973618877347725,0.0021973618877347725,0.0021428514891337885]
#
# ('SP', 'GO', '947', ' 4700', '4.9630')
# features (Características do dado)= (283,[1,251],[1.0,1.0])
# label = 12.0 <-> prob = 2.0
# prediction = [0.1407855675489241,0.08009168597587488,0.18317983967921755,0.09337350956054993,0.07383048558732705,0.05704991484490964,0.07348708987371345,0.039075215771311136,0.037320718837610886,0.033429600710254435,0.034397795989569074,0.025456462009697128,0.020781401508405867,0.017450724126526675,0.018238145166479577,0.0144959603692718,0.012415440419878293,0.011126029042061626,0.005304968982491583,0.004629139205215392,0.004942811434336467,0.005183519251023432,0.002833275154928108,0.002833275154928108,0.0028332751549281104,0.0028332751549281104,0.002620873485637221]
#
# ('SP', 'PR', '1072', ' 3500', '3.2649')
# features (Características do dado)= (283,[1,193],[1.0,1.0])
# label = 10.0 <-> prob = 2.0
# prediction = [0.1407855675489241,0.08009168597587488,0.18317983967921755,0.09337350956054993,0.07383048558732705,0.05704991484490964,0.07348708987371345,0.039075215771311136,0.037320718837610886,0.033429600710254435,0.034397795989569074,0.025456462009697128,0.020781401508405867,0.017450724126526675,0.018238145166479577,0.0144959603692718,0.012415440419878293,0.011126029042061626,0.005304968982491583,0.004629139205215392,0.004942811434336467,0.005183519251023432,0.002833275154928108,0.002833275154928108,0.0028332751549281104,0.0028332751549281104,0.002620873485637221]
#
# ('SP', 'SP', '162', ' 25', '0.1543')
# features (Características do dado)= (283,[1,72],[1.0,1.0])
# label = 2.0 <-> prob = 2.0
# prediction = [0.1407855675489241,0.08009168597587488,0.18317983967921755,0.09337350956054993,0.07383048558732705,0.05704991484490964,0.07348708987371345,0.039075215771311136,0.037320718837610886,0.033429600710254435,0.034397795989569074,0.025456462009697128,0.020781401508405867,0.017450724126526675,0.018238145166479577,0.0144959603692718,0.012415440419878293,0.011126029042061626,0.005304968982491583,0.004629139205215392,0.004942811434336467,0.005183519251023432,0.002833275154928108,0.002833275154928108,0.0028332751549281104,0.0028332751549281104,0.002620873485637221]
#
# ('SP', 'SP', '304', ' 1200', '3.9474')
# features (Características do dado)= (283,[1,216],[1.0,1.0])
# label = 2.0 <-> prob = 2.0
# prediction = [0.1407855675489241,0.08009168597587488,0.18317983967921755,0.09337350956054993,0.07383048558732705,0.05704991484490964,0.07348708987371345,0.039075215771311136,0.037320718837610886,0.033429600710254435,0.034397795989569074,0.025456462009697128,0.020781401508405867,0.017450724126526675,0.018238145166479577,0.0144959603692718,0.012415440419878293,0.011126029042061626,0.005304968982491583,0.004629139205215392,0.004942811434336467,0.005183519251023432,0.002833275154928108,0.002833275154928108,0.0028332751549281104,0.0028332751549281104,0.002620873485637221]
#
# ('TO', 'GO', '625', ' 1000', '1.6000')
# features (Características do dado)= (283,[143],[1.0])
# label = 12.0 <-> prob = 0.0
# prediction = [0.15633443402673158,0.11121837052001704,0.11148751574766404,0.1018219523806829,0.09365150191820035,0.06512212472034551,0.05823613213266333,0.04570189130462815,0.04328709104346077,0.03952070420616679,0.027987233548519938,0.024704478007792033,0.0180545881145769,0.018255053966885135,0.016911048414537118,0.013097387110992308,0.01104607975924391,0.010719451122689863,0.005406236232180412,0.004466832008282723,0.004780463154109016,0.004777832806342039,0.002695802117348259,0.002695802117348259,0.002695802117348261,0.002695802117348261,0.002628389283894966]

# %%
i = 0
print (test.columns[0:5])
for row in result:
    print (test.collect()[i][:5])
    i += 1
    print("label = %s <-> prob = %s\n"
          % (row.label,  row.prediction))
# Out:
# ['uf_ori', 'uf_dst', 'km', 'preco', 'preco_km']
# ('BA', 'BA', '517', ' 2500', '4.8356')
# label = 3.0 <-> prob = 3.0
#
# ('BA', 'BA', '517', ' 2500', '4.8356')
# label = 3.0 <-> prob = 3.0
#
# ('BA', 'PA', '2033', ' 7850', '3.8613')
# label = 7.0 <-> prob = 7.0
#
# ('BA', 'PB', '921', ' 3900', '4.2345')
# label = 9.0 <-> prob = 9.0
#
# ('BA', 'PE', '706', ' 3750', '5.3116')
# label = 4.0 <-> prob = 4.0
#
# ('BA', 'PE', '805', ' 3750', '4.6584')
# label = 4.0 <-> prob = 4.0
#
# ('BA', 'RJ', '1629', ' 6200', '3.8060')
# label = 0.0 <-> prob = 0.0
#
# ('BA', 'RJ', '1629', ' 6200', '3.8060')
# label = 0.0 <-> prob = 0.0
#
# ('PA', 'CE', '1660', ' 6500', '3.9157')
# label = 5.0 <-> prob = 2.0
#
# ('PB', 'SP', '2703', ' 6000', '2.2198')
# label = 2.0 <-> prob = 4.0
#
# ('RS', 'RS', '123', ' 24', '0.1951')
# label = 1.0 <-> prob = 1.0
#
# ('RS', 'RS', '123', ' 24', '0.1951')
# label = 1.0 <-> prob = 1.0
#
# ('RS', 'RS', '211', ' 31', '0.1469')
# label = 1.0 <-> prob = 1.0
#
# ('RS', 'RS', '284', ' 44', '0.1549')
# label = 1.0 <-> prob = 1.0
#
# ('SE', 'RS', '3255', ' 8000', '2.4578')
# label = 1.0 <-> prob = 3.0
#
# ('SP', 'GO', '947', ' 4700', '4.9630')
# label = 12.0 <-> prob = 2.0
#
# ('SP', 'PR', '1072', ' 3500', '3.2649')
# label = 10.0 <-> prob = 2.0
#
# ('SP', 'SP', '162', ' 25', '0.1543')
# label = 2.0 <-> prob = 2.0
#
# ('SP', 'SP', '304', ' 1200', '3.9474')
# label = 2.0 <-> prob = 2.0
#
# ('TO', 'GO', '625', ' 1000', '1.6000')
# label = 12.0 <-> prob = 0.0
